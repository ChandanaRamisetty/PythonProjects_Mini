# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from bs4 import BeautifulSoup
import requests

# %%
from csv import writer

# %%
url="https://finance.yahoo.com/cryptocurrencies/"
User={"User-Agent": "Chrome/104.0.5112.102"}
GetData=requests.get(url,headers=User)
print(GetData)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(GetData.content,'html.parser')

# %%
Lists=soup.find("div",{"class":"Ovx(a) Ovx(h)--print Ovy(h) W(100%)"})
print(Lists)
# Out:
# <div class="Ovx(a) Ovx(h)--print Ovy(h) W(100%)"><table class="W(100%)"><thead><tr class="C($tertiaryColor) BdB Bdbc($seperatorColor)"><th class="Ta(start) Pstart(6px) Pend(10px) Whs(nw) Miw(90px) Bgc($lv3BgColor) Fz(xs) Va(m) Py(5px)! Cur(p) Bgc($hoverBgColor):h Fw(400)! Ta(start) Start(0) Pend(10px) Pos(st) Bgc($lv3BgColor) Z(1) Ta(start)!"><label class="Ta(c) Pos(r) Va(tb) Pend(5px) D(n)--print" data-id=""><input class="Pos(a) V(h)" type="checkbox"/><svg class="Va(m)! H(16px) W(16px) Stk($plusGray)! Fill($plusGray)! Cur(p)" data-icon="checkbox-unchecked" height="16" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom" viewbox="0 0 24 24" width="16"><path d="M3 3h18v18H3V3zm19-2H2c-.553 0-1 .448-1 1v20c0 .552.447 1 1 1h20c.552 0 1-.448 1-1V2c0-.552-.448-1-1-1z"></path></svg></label>Symbol<div class="W(3px) Pend(5px) Pos(a) Start(100%) T(0) H(100%) Bg($pfColumnFakeShadowGradient) Pe(n)"></div></th><th class="Ta(start) Px(10px) Bgc($lv3BgColor) Fz(xs) Va(m) Py(5px)! Cur
# ...

# %%
dfff={}
with open('ikea.csv', 'w', encoding='utf8', newline='') as w:
    thewriter = writer(w)
    header = ['Name','Price','Change','Percentage,','MarketCap','Volume Since','Volume oneday','TotalVolume','Supply']
    
    thewriter.writerow(header)
    for l in Lists:
        rows=l.find_all('tr',{"class":"simpTblRow Bgc($hoverBgColor):h BdB Bdbc($seperatorColor) Bdbc($tableBorderBlue):h H(32px) Bgc($lv2BgColor)"})
        for i in rows:
            print(i.get_text(separator="|"))
            Name=i.find('td',{"class":"Va(m) Ta(start) Px(10px) Fz(s)"}).get_text()
            Price=i.find('td',{"class":"Va(m) Ta(end) Pstart(20px) Fw(600) Fz(s)"}).get_text()
            Change=i.find('td',{"class":"Va(m) Ta(end) Pstart(20px) Fw(600) Fz(s)"}).get_text()
            Percentage=i.find('td',{"class":"Va(m) Ta(end) Pstart(20px) Fw(600) Fz(s)"}).get_text()
            MarketCap=i.find('td',{"class":"Va(m) Ta(end) Pstart(20px) Fz(s)"}).get_text()
            VolumeSince=i.find('td',{"class":"Va(m) Ta(start) Px(10px) Fz(s)"}).get_text()
            Volumeoneday=i.find('td',{"class":"Va(m) Ta(start) Px(10px) Fz(s)"}).get_text()
            TotalVolume=i.find('td',{"class":"Va(m) Ta(start) Px(10px) Fz(s)"}).get_text()
            Supply=i.find('td',{"class":"Va(m) Ta(start) Px(10px) Fz(s)"}).get_text()
            header=[Name,Price,Change,Percentage,MarketCap,VolumeSince,Volumeoneday,TotalVolume,Supply]
            print(header)
            thewriter.writerow(header)
dfff=pd.read_csv("ikea.csv")
print(dfff)
# Out:
# BTC-USD|Bitcoin USD|19,779.76|-67.53|-0.34%|378.604B|23.923B|23.923B|23.923B|19.141M
# ['Bitcoin USD', '19,779.76', '19,779.76', '19,779.76', '378.604B', 'Bitcoin USD', 'Bitcoin USD', 'Bitcoin USD', 'Bitcoin USD']
# USDT-USD|Tether USD|0.999994|-0.000080|-0.01%|67.55B|29.598B|29.598B|29.598B|67.55B
# ['Tether USD', '0.999994', '0.999994', '0.999994', '67.55B', 'Tether USD', 'Tether USD', 'Tether USD', 'Tether USD']
# BNB-USD|BNB USD|278.42|+1.96|+0.71%|44.919B|478.406M|478.406M|478.406M|161.337M
# ['BNB USD', '278.42', '278.42', '278.42', '44.919B', 'BNB USD', 'BNB USD', 'BNB USD', 'BNB USD']
# ADA-USD|Cardano USD|0.496849|+0.028383|+6.06%|16.983B|894.089M|894.089M|894.089M|34.182B
# ['Cardano USD', '0.496849', '0.496849', '0.496849', '16.983B', 'Cardano USD', 'Cardano USD', 'Cardano USD', 'Cardano USD']
# SOL-USD|Solana USD|31.62|+0.50|+1.61%|11.063B|326.037M|326.037M|326.037M|349.84M
# ...

# %%
print(dfff)
# Out:
#                    Name      Price     Change Percentage, MarketCap  \
# 0           Bitcoin USD  19,779.76  19,779.76   19,779.76  378.604B
# 1            Tether USD   0.999994   0.999994    0.999994    67.55B
# 2               BNB USD     278.42     278.42      278.42   44.919B
# 3           Cardano USD   0.496849   0.496849    0.496849   16.983B
# 4            Solana USD      31.62      31.62       31.62   11.063B
# 5          Polkadot USD     7.2403     7.2403      7.2403    8.103B
# 6               HEX USD   0.042752   0.042752    0.042752    7.414B
# 7               Dai USD   0.999445   0.999445    0.999445    6.959B
# 8              TRON USD   0.063050   0.063050    0.063050    5.825B
# 9   Lido Staked ETH USD   1,508.62   1,508.62    1,508.62    5.262B
# 10  Wrapped Bitcoin USD  19,778.23  19,778.23   19,778.23    4.906B
# 11          yOUcash USD   0.511397   0.511397    0.511397    4.407B
# 12         Litecoin USD      60.05      60.05       60.05    4.269B
#
# ...

# %%
New_df=dfff[(dfff['Supply']=='BNB USD')]
print(New_df.head())
# Out:
#       Name   Price  Change Percentage, MarketCap Volume Since Volume oneday  \
# 2  BNB USD  278.42  278.42      278.42   44.919B      BNB USD       BNB USD
#
#   TotalVolume   Supply
# 2     BNB USD  BNB USD

# %%
print(dfff.dtypes)
print(dfff.columns)
print(dfff['Price'])
# Out:
# Name             object
# Price            object
# Change           object
# Percentage,      object
# MarketCap        object
# Volume Since     object
# Volume oneday    object
# TotalVolume      object
# Supply           object
# dtype: object
# Index(['Name', 'Price', 'Change', 'Percentage,', 'MarketCap', 'Volume Since',
#        'Volume oneday', 'TotalVolume', 'Supply'],
#       dtype='object')
# 0     19,779.76
# 1      0.999994
# 2        278.42
# 3      0.496849
# 4         31.62
# 5        7.2403
# 6      0.042752
# 7      0.999445
# 8      0.063050
# 9      1,508.62
# 10    19,778.23
# 11     0.511397
# 12        60.05
# Name: Price, dtype: object

# %%
df={}
Lists=soup.find("div",{"class":"Ovx(a) Ovx(h)--print Ovy(h) W(100%)"})
print(Lists)
for i in Lists:
    ind_rows=i.find_all('tr',{"class":"simpTblRow Bgc($hoverBgColor):h BdB Bdbc($seperatorColor) Bdbc($tableBorderBlue):h H(32px) Bgc($lv2BgColor)"})
    for j in ind_rows:
        p=j.get_text(separator="|")
        print(p)
        df[j.get_text(separator="|").split("|")[0]]=j.get_text(separator="|").split("|")[1:]
        print()
display(df)
# Out:
# <div class="Ovx(a) Ovx(h)--print Ovy(h) W(100%)"><table class="W(100%)"><thead><tr class="C($tertiaryColor) BdB Bdbc($seperatorColor)"><th class="Ta(start) Pstart(6px) Pend(10px) Whs(nw) Miw(90px) Bgc($lv3BgColor) Fz(xs) Va(m) Py(5px)! Cur(p) Bgc($hoverBgColor):h Fw(400)! Ta(start) Start(0) Pend(10px) Pos(st) Bgc($lv3BgColor) Z(1) Ta(start)!"><label class="Ta(c) Pos(r) Va(tb) Pend(5px) D(n)--print" data-id=""><input class="Pos(a) V(h)" type="checkbox"/><svg class="Va(m)! H(16px) W(16px) Stk($plusGray)! Fill($plusGray)! Cur(p)" data-icon="checkbox-unchecked" height="16" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom" viewbox="0 0 24 24" width="16"><path d="M3 3h18v18H3V3zm19-2H2c-.553 0-1 .448-1 1v20c0 .552.447 1 1 1h20c.552 0 1-.448 1-1V2c0-.552-.448-1-1-1z"></path></svg></label>Symbol<div class="W(3px) Pend(5px) Pos(a) Start(100%) T(0) H(100%) Bg($pfColumnFakeShadowGradient) Pe(n)"></div></th><th class="Ta(start) Px(10px) Bgc($lv3BgColor) Fz(xs) Va(m) Py(5px)! Cur
# ...
